# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 27.8 MB/s eta 0:00:0000:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.7 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.5 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 2.0 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 27.6 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 13.5 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 8.3 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 88.0 MB/s eta 0:00:00:00:0100:01
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.9.41
#     Uninstalling nvidia-nvjitlink-cu12-12.9.41:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.9.41
# ...

# %%
# !gdown --id 13Nc-txqQyNNYdM9LJ59l-t_Uaa_WZE7-
# Out:
# /usr/local/lib/python3.11/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=13Nc-txqQyNNYdM9LJ59l-t_Uaa_WZE7-
# From (redirected): https://drive.google.com/uc?id=13Nc-txqQyNNYdM9LJ59l-t_Uaa_WZE7-&confirm=t&uuid=a6e0fbc0-1d2f-473f-a684-5cd5d109b135
# To: /kaggle/working/Bike Helmet Detection.v2-more-preprocessing-augmentation.yolov8.zip
# 100%|████████████████████████████████████████| 122M/122M [00:01<00:00, 81.1MB/s]

# %%
# !unzip 'Bike Helmet Detection.v2-more-preprocessing-augmentation.yolov8.zip'
# Out:
# Archive:  Bike Helmet Detection.v2-more-preprocessing-augmentation.yolov8.zip
#  extracting: README.dataset.txt
#  extracting: README.roboflow.txt
#  extracting: data.yaml
#    creating: test/
#    creating: test/images/
#  extracting: test/images/BikesHelmets102_png_jpg.rf.6bc6d292ee31801b348ecd1b3ff56e58.jpg
#  extracting: test/images/BikesHelmets150_png_jpg.rf.347400d070a36faf53bd1ace27a3dd43.jpg
#  extracting: test/images/BikesHelmets162_png_jpg.rf.afa7afdd78e5dd465e07020c8f6f8743.jpg
#  extracting: test/images/BikesHelmets163_png_jpg.rf.bc2e75700813e81ee03981e79151f0ac.jpg
#  extracting: test/images/BikesHelmets176_png_jpg.rf.80db740fa43cad753ab10b2c62fa7bc6.jpg
#  extracting: test/images/BikesHelmets18_png_jpg.rf.84a3bd2569cd63e920de9c89d731bd7c.jpg
#  extracting: test/images/BikesHelmets220_png_jpg.rf.2511258c37c57287f2b13f1b83689b57.jpg
#  extracting: test/images/BikesHelmets225_png_jpg.rf.5ce1ddd4bfc514cfcc4497d40916d466.jpg
# ...

# %%
# !ls
# Out:
# 'Bike Helmet Detection.v2-more-preprocessing-augmentation.yolov8.zip'   test
#  data.yaml							        train
#  README.dataset.txt						        valid
#  README.roboflow.txt

# %%
from ultralytics import YOLO
model = YOLO("yolov8n.pt")
model.train(
    data="data.yaml",
    epochs=500,
    imgsz= 736,
    mixup=0.1,
    mosaic=1.0,
    fliplr=0.5,
    batch=16,
    lr0=0.005,
    lrf=0.1,
    momentum = 0.9,
    weight_decay = 0.0005,
    hsv_h=0.015, hsv_s=0.7, hsv_v=0.4,
    cache=True,
    name="Helmet",
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 109MB/s]
# Ultralytics 8.3.163 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# ...

# %%
model=YOLO("runs/detect/train/weights/best.pt")
model.val()

# %%
model = YOLO("runs/detect/train/weights/best.pt")
results = model.predict(source="/conten t/helmet_dataset/test/images", save=True)

# %%
from IPython.display import Image, display
import os

# Path to prediction folder
pred_folder = "runs/detect/predict"

# Display all predicted imagefor image_name in os.listdir(pred_folder):
    if image_name.endswith((".jpg", ".png")):
        display(Image(filename=os.path.join(pred_folder, image_name)))

# %%
from PIL import Image as PILImage
import IPython.display as disp

# Sort by file size to show most 'eventful' image
images = sorted(os.listdir(pred_folder), key=lambda x: os.path.getsize(os.path.join(pred_folder, x)), reverse=True)
disp.display(PILImage.open(os.path.join(pred_folder, images[0])))

# %%
# Run validation and capture metrics
metrics = model.val()

# Print key metrics
print(f"mAP50: {metrics.box.map50:.4f}")      # mAP at IoU=0.50
print(f"mAP50-95: {metrics.box.map:.4f}")     # mAP@[.50:.95] (COCO-style)
print(f"Precision: {metrics.box.p[0]:.4f}") # Access the first element for overall precision
print(f"Recall: {metrics.box.r[0]:.4f}")    # Access the first element for overall recall

# %%
import matplotlib.pyplot as plt

metrics = model.val()
maps = metrics.box.maps.tolist()

# Plot mAP per class
plt.bar(range(len(maps)), maps)
plt.title("mAP@[.50:.95] per class")
plt.xlabel("Class ID")
plt.ylabel("mAP")
plt.show()

# %%
model.predict(source="/content/video1.mp4", save=True)
